# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd 
import numpy as np 
from datetime import datetime, timedelta
from ukpn_flex_savings.services.ukpn_flex_dispatches import ukpn_flex_dispatches_service
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
my_flex_dispatches = ukpn_flex_dispatches_service.fetch_dispatches(
    start_time=datetime(2024, 1, 1),
    end_time=datetime(2025, 1, 1)
)
# Out:
# {'total_count': 37785, 'results': [{'company_name': 'Axle Energy Limited', 'fu_id': 'waddesdon-lt_saou-ev-c1-portfolio', 'zone': 'Waddesdon', 'product': 'Scheduled Availability', 'start_time_local': '2025-07-16T09:00:00+00:00', 'end_time_local': '2025-07-16T13:00:00+00:00', 'availability_mw_req': 0.019, 'utilisation_mw_req': 0.0, 'availability_price': 32.0, 'utilisation_price': 0.0, 'availability_mwh_req': 0.08, 'utilisation_mwh_req': 0.0, 'technology': 'EV Charger DSR', 'dispatch_type': 'demand_turn_down', 'hours_requested': 4.0, 'dispatch_method': 'epex', 'start_time_utc': '2025-07-16 09:00:00+00:00', 'end_time_utc': '2025-07-16 13:00:00+00:00', 'time_utc': '09:00:00+00:00'}, {'company_name': 'Axle Energy Limited', 'fu_id': 'kenninghall-lt_saou-ev-c1-portfolio', 'zone': 'Kenninghall', 'product': 'Scheduled Availability', 'start_time_local': '2025-11-18T11:00:00+00:00', 'end_time_local': '2025-11-18T15:00:00+00:00', 'availability_mw_req': 0.011, 'utilisation_mw_req': 0.0, 'availabil
# ...

# %%
my_flex_dispatches
# Out:
# shape: (5, 19)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ company_n ┆ fu_id     ┆ zone      ┆ product   ┆ … ┆ dispatch_ ┆ start_tim ┆ end_time_ ┆ time_utc │
# │ ame       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ method    ┆ e_utc     ┆ utc       ┆ ---      │
# │ ---       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ str      │
# │ str       ┆           ┆           ┆           ┆   ┆ str       ┆ str       ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Axle      ┆ waddesdon ┆ Waddesdon ┆ Scheduled ┆ … ┆ epex      ┆ 2025-07-1 ┆ 2025-07-1 ┆ 09:00:00 │
# │ Energy    ┆ -lt_saou- ┆           ┆ Availabil ┆   ┆           ┆ 6 09:00:0 ┆ 6 13:00:0 ┆ +00:00   │
# │ Limited   ┆ ev-c1-por ┆           ┆ ity       ┆   ┆           ┆ 0+00:00   ┆ 0+00:00   ┆          │
# ...

# %%
# Out:
# '6538945f649be5fd1563bf085dec2fd82168021ea9bfe722c7e21f36'

# %%
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 my_flex_dispatches.fetch_dispatches(start_time=start_time, end_time=end_time)
#
# File ~/projects/ukpn-flex-savings/src/ukpn_flex_savings/services/ukpn_flex_dispatches.py:22, in UKPNFlexDispatchesService.fetch_dispatches(self, start_time, end_time)
#      16 params = {
#      17     "start_time": start_time.isoformat(),
#      18     "end_time": end_time.isoformat(),
#      19     "api_key": self.api_key,
#      20 }
#      21 response = httpx.get(self.dispatch_url, params=params)
# ---> 22 response.raise_for_status()
#      23 data = response.json()
#      24 records = data.get("records", [])
#
# File ~/projects/ukpn-flex-savings/.venv/lib/python3.14/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     827 error_type = error_types.get(status_class, "Invalid status code")
# ...
